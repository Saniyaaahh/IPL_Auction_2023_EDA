# %% [markdown]
# # IPL AUCTION 2023

# %% [raw]
# Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Loading DATASET

# %%
data=pd.read_csv(r"IPL_Squad_2023_Auction_Dataset.csv")
data
# Out:
#      Unnamed: 0      Player's List Base Price          TYPE  COST IN ₹ (CR.)  \
# 0             0        Shivam Mavi    4000000        BOWLER              6.0
# 1             1      Joshua Little    5000000        BOWLER              4.4
# 2             2    Kane Williamson   20000000       BATSMAN              2.0
# 3             3        K.S. Bharat    2000000  WICKETKEEPER              1.2
# 4             4       Mohit Sharma    5000000        BOWLER              0.5
# ..          ...                ...        ...           ...              ...
# 563         563        Dhruv Patel    2000000   ALL-ROUNDER              NaN
# 564         564    Jack Prestwidge    2000000   ALL-ROUNDER              NaN
# 565         565     Aditya Sarvate    2000000   ALL-ROUNDER              NaN
# 566         566      Sagar Solanki    2000000   ALL-ROUNDER              NaN
# 567         567  Prenelan Subrayen    2000000   ALL-ROUNDER              NaN
#
#      Cost IN $ (000) 2022 Squad            Team
# 0              720.0        KKR  Gujarat Titans
# 1              528.0        NaN  Gujarat Titans
# 2              240.0        SRH  Gujarat Titans
# 3              144.0         DC  Gujarat Titans
# 4               60.0        NaN  Gujarat Titans
# ..               ...        ...             ...
# 563              NaN        NaN          Unsold
# 564              NaN        NaN          Unsold
# 565              NaN        NaN          Unsold
# 566              NaN        NaN          Unsold
# 567              NaN        NaN          Unsold
#
# [568 rows x 8 columns]

# %% [markdown]
# ### Dropping unnecessary columns

# %%
data.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
data.head()
# Out:
#      Player's List Base Price          TYPE  COST IN ₹ (CR.)  Cost IN $ (000)  \
# 0      Shivam Mavi    4000000        BOWLER              6.0            720.0
# 1    Joshua Little    5000000        BOWLER              4.4            528.0
# 2  Kane Williamson   20000000       BATSMAN              2.0            240.0
# 3      K.S. Bharat    2000000  WICKETKEEPER              1.2            144.0
# 4     Mohit Sharma    5000000        BOWLER              0.5             60.0
#
#   2022 Squad            Team
# 0        KKR  Gujarat Titans
# 1        NaN  Gujarat Titans
# 2        SRH  Gujarat Titans
# 3         DC  Gujarat Titans
# 4        NaN  Gujarat Titans

# %% [markdown]
# ### Basic Analysis

# %%
data.describe()
# Out:
#        COST IN ₹ (CR.)  Cost IN $ (000)
# count       243.000000       243.000000
# mean          0.687243        82.469136
# std           2.511700       301.404032
# min           0.000000         0.000000
# 25%           0.000000         0.000000
# 50%           0.000000         0.000000
# 75%           0.200000        24.000000
# max          18.500000      2220.000000

# %%
data.dtypes
# Out:
# Player's List       object
# Base Price          object
# TYPE                object
# COST IN ₹ (CR.)    float64
# Cost IN $ (000)    float64
# 2022 Squad          object
# Team                object
# dtype: object

# %%
data.isna().sum()
# Out:
# Player's List        0
# Base Price           0
# TYPE                 0
# COST IN ₹ (CR.)    325
# Cost IN $ (000)    325
# 2022 Squad         338
# Team                 0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568 entries, 0 to 567
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Player's List    568 non-null    object
#  1   Base Price       568 non-null    object
#  2   TYPE             568 non-null    object
#  3   COST IN ₹ (CR.)  243 non-null    float64
#  4   Cost IN $ (000)  243 non-null    float64
#  5   2022 Squad       230 non-null    object
#  6   Team             568 non-null    object
# dtypes: float64(2), object(5)
# memory usage: 31.2+ KB

# %%
data.count()
# Out:
# Player's List      568
# Base Price         568
# TYPE               568
# COST IN ₹ (CR.)    243
# Cost IN $ (000)    243
# 2022 Squad         230
# Team               568
# dtype: int64

# %%
data.shape
# Out:
# (568, 7)

# %%
data = data[pd.to_numeric(data['Base Price'], errors='coerce').notna()]

# %%
data['Base Price'] = data['Base Price'].astype(float)
data
# Out:
#          Player's List  Base Price          TYPE  COST IN ₹ (CR.)  \
# 0          Shivam Mavi   4000000.0        BOWLER              6.0
# 1        Joshua Little   5000000.0        BOWLER              4.4
# 2      Kane Williamson  20000000.0       BATSMAN              2.0
# 3          K.S. Bharat   2000000.0  WICKETKEEPER              1.2
# 4         Mohit Sharma   5000000.0        BOWLER              0.5
# ..                 ...         ...           ...              ...
# 563        Dhruv Patel   2000000.0   ALL-ROUNDER              NaN
# 564    Jack Prestwidge   2000000.0   ALL-ROUNDER              NaN
# 565     Aditya Sarvate   2000000.0   ALL-ROUNDER              NaN
# 566      Sagar Solanki   2000000.0   ALL-ROUNDER              NaN
# 567  Prenelan Subrayen   2000000.0   ALL-ROUNDER              NaN
#
#      Cost IN $ (000) 2022 Squad            Team
# 0              720.0        KKR  Gujarat Titans
# 1              528.0        NaN  Gujarat Titans
# 2              240.0        SRH  Gujarat Titans
# 3              144.0         DC  Gujarat Titans
# 4               60.0        NaN  Gujarat Titans
# ..               ...        ...             ...
# 563              NaN        NaN          Unsold
# 564              NaN        NaN          Unsold
# 565              NaN        NaN          Unsold
# 566              NaN        NaN          Unsold
# 567              NaN        NaN          Unsold
#
# [405 rows x 7 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 405 entries, 0 to 567
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Player's List    405 non-null    object
#  1   Base Price       405 non-null    float64
#  2   TYPE             405 non-null    object
#  3   COST IN ₹ (CR.)  80 non-null     float64
#  4   Cost IN $ (000)  80 non-null     float64
#  5   2022 Squad       67 non-null     object
#  6   Team             405 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 25.3+ KB

# %% [markdown]
# The players who went unsold and the players who did not play last year IPL has got null values

# %% [markdown]
# ### Data Cleaning

# %%
# Replacing null values

data['COST IN ₹ (CR.)'].fillna(0, inplace = True)
data['Cost IN $ (000)'].fillna(0, inplace = True)

# %%
# Replacing Null values of 2022 Squad column with DNP as the players did not play 2022 IPL Season
data['2022 Squad'].fillna('DNP', inplace = True)

# %% [markdown]
# ### Verifying changes

# %%
data.isnull().sum()
# Out:
# Player's List      0
# Base Price         0
# TYPE               0
# COST IN ₹ (CR.)    0
# Cost IN $ (000)    0
# 2022 Squad         0
# Team               0
# dtype: int64

# %%
data.head()
# Out:
#      Player's List Base Price          TYPE  COST IN ₹ (CR.)  Cost IN $ (000)  \
# 0      Shivam Mavi    4000000        BOWLER              6.0            720.0
# 1    Joshua Little    5000000        BOWLER              4.4            528.0
# 2  Kane Williamson   20000000       BATSMAN              2.0            240.0
# 3      K.S. Bharat    2000000  WICKETKEEPER              1.2            144.0
# 4     Mohit Sharma    5000000        BOWLER              0.5             60.0
#
#   2022 Squad            Team
# 0        KKR  Gujarat Titans
# 1        DNP  Gujarat Titans
# 2        SRH  Gujarat Titans
# 3         DC  Gujarat Titans
# 4        DNP  Gujarat Titans

# %% [markdown]
# Hence Values are replaced and our Data is Cleaned for further Analysis

# %% [markdown]
# ### Q1) List of players with base price above 1.5 crores

# %%
df_above_15m = data[data['Base Price'] > 15000000].copy()

# %%
df_above_15m
# Out:
#              Player's List  Base Price          TYPE  COST IN ₹ (CR.)  \
# 2          Kane Williamson  20000000.0       BATSMAN             2.00
# 25              Ben Stokes  20000000.0   ALL-ROUNDER            16.25
# 51           Rilee Rossouw  20000000.0       BATSMAN             4.60
# 53               Phil Salt  20000000.0  WICKETKEEPER             2.00
# 97              Sam Curran  20000000.0   ALL-ROUNDER            18.50
# 119        Nicholas Pooran  20000000.0  WICKETKEEPER            16.00
# 144          Cameron Green  20000000.0   ALL-ROUNDER            17.50
# 193           Jason Holder  20000000.0   ALL-ROUNDER             5.75
# 222            Adil Rashid  20000000.0        BOWLER             2.00
# 243             Tom Banton  20000000.0  WICKETKEEPER             0.00
# 245           Chris Jordan  20000000.0        BOWLER             0.00
# 246             Adam Milne  20000000.0        BOWLER             0.00
# 267            Travis Head  20000000.0       BATSMAN             0.00
# 271  Rassie Van Der Dussen  20000000.0       BATSMAN             0.00
# 274          Jimmy Neesham  20000000.0   ALL-ROUNDER             0.00
# 330             Chris Lynn  20000000.0       BATSMAN             0.00
# 344          Jamie Overton  20000000.0   ALL-ROUNDER             0.00
# 408          Craig Overton  20000000.0   ALL-ROUNDER             0.00
# 418            Tymal Mills  20000000.0        BOWLER             0.00
#
#      Cost IN $ (000) 2022 Squad                  Team
# 2              240.0        SRH        Gujarat Titans
# 25            1950.0        DNP   Chennai Super Kings
# 51             552.0        DNP        Delhi Capitals
# 53             240.0        DNP        Delhi Capitals
# 97            2220.0        DNP    Punjab Super Kings
# 119           1920.0        SRH  Lucknow Super Giants
# 144           2100.0        DNP        Mumbai Indians
# 193            690.0        LSG      Rajasthan Royals
# 222            240.0        DNP   Sunrisers Hyderabad
# 243              0.0        DNP                Unsold
# 245              0.0        CSK                Unsold
# 246              0.0        CSK                Unsold
# 267              0.0        DNP                Unsold
# 271              0.0         RR                Unsold
# 274              0.0         RR                Unsold
# 330              0.0        DNP                Unsold
# 344              0.0        DNP                Unsold
# 408              0.0        DNP                Unsold
# 418              0.0         MI                Unsold

# %% [markdown]
# ### Q2) List of players with base price above 50 lacks and below 1.5 crores

# %%
df_below_15m = data[(data['Base Price'] < 15000000) & (data['Base Price'] > 5000000)].copy()

# %%
df_below_15m
# Out:
#          Player's List  Base Price          TYPE  COST IN ₹ (CR.)  \
# 26       Kyle Jamieson  10000000.0        BOWLER             1.00
# 52       Manish Pandey  10000000.0       BATSMAN             2.40
# 76         David Wiese  10000000.0   ALL-ROUNDER             1.00
# 120        Daniel Sams   7500000.0   ALL-ROUNDER             0.75
# 169       Reece Topley   7500000.0        BOWLER             1.90
# 195           Joe Root  10000000.0       BATSMAN             1.00
# 219     Mayank Agarwal  10000000.0       BATSMAN             8.25
# 220   Heinrich Klaasen  10000000.0  WICKETKEEPER             5.25
# 224       Akeal Hosein  10000000.0        BOWLER             1.00
# 247      Mujeeb Rahman  10000000.0        BOWLER             0.00
# 248     Tabraiz Shamsi  10000000.0        BOWLER             0.00
# 272     Daryl Mitchell  10000000.0   ALL-ROUNDER             0.00
# 273      Mohammad Nabi  10000000.0   ALL-ROUNDER             0.00
# 275      Wayne Parnell   7500000.0   ALL-ROUNDER             0.00
# 284          Shai Hope  10000000.0  WICKETKEEPER             0.00
# 285         Tom Latham  10000000.0  WICKETKEEPER             0.00
# 286    Joshua Philippe   7500000.0  WICKETKEEPER             0.00
# 289          Ish Sodhi   7500000.0        BOWLER             0.00
# 340  Michael Bracewell  10000000.0   ALL-ROUNDER             0.00
# 351         Andrew Tye  10000000.0        BOWLER             0.00
# 352          Luke Wood  10000000.0        BOWLER             0.00
# 403         Tom Curran   7500000.0   ALL-ROUNDER             0.00
# 404   Moises Henriques  10000000.0   ALL-ROUNDER             0.00
# 409        Darcy Short   7500000.0   ALL-ROUNDER             0.00
# 416         Matt Henry  10000000.0        BOWLER             0.00
# 419        David Payne   7500000.0        BOWLER             0.00
# 472  Carlos Brathwaite   7500000.0   ALL-ROUNDER             0.00
# 473       Roston Chase  10000000.0   ALL-ROUNDER             0.00
# 474   Rahkeem Cornwall  10000000.0   ALL-ROUNDER             0.00
#
#      Cost IN $ (000) 2022 Squad                        Team
# 26             120.0        DNP         Chennai Super Kings
# 52             288.0        LSG              Delhi Capitals
# 76             120.0        DNP       Kolkata Knight Riders
# 120             90.0         MI        Lucknow Super Giants
# 169            228.0        DNP  Royal Challengers Banglore
# 195            120.0        DNP            Rajasthan Royals
# 219            990.0       PBKS         Sunrisers Hyderabad
# 220            630.0        DNP         Sunrisers Hyderabad
# 224            120.0        DNP         Sunrisers Hyderabad
# 247              0.0        DNP                      Unsold
# 248              0.0        DNP                      Unsold
# 272              0.0         RR                      Unsold
# 273              0.0        KKR                      Unsold
# 275              0.0        DNP                      Unsold
# 284              0.0        DNP                      Unsold
# 285              0.0        DNP                      Unsold
# 286              0.0        DNP                      Unsold
# 289              0.0        DNP                      Unsold
# 340              0.0        DNP                      Unsold
# 351              0.0        LSG                      Unsold
# 352              0.0        DNP                      Unsold
# 403              0.0        DNP                      Unsold
# 404              0.0        DNP                      Unsold
# 409              0.0        DNP                      Unsold
# 416              0.0        DNP                      Unsold
# 419              0.0        DNP                      Unsold
# 472              0.0        DNP                      Unsold
# 473              0.0        DNP                      Unsold
# 474              0.0        DNP                      Unsold

# %% [markdown]
# ### Q3) Top 10 Expensive Players sold

# %%
top_10_expensive_batsmen = data.nlargest(10, 'COST IN ₹ (CR.)')[["Player's List", 'COST IN ₹ (CR.)']]

# %%
top_10_expensive_batsmen
# Out:
#         Player's List  COST IN ₹ (CR.)
# 97         Sam Curran            18.50
# 144     Cameron Green            17.50
# 25         Ben Stokes            16.25
# 119   Nicholas Pooran            16.00
# 218       Harry Brook            13.25
# 219    Mayank Agarwal             8.25
# 0         Shivam Mavi             6.00
# 193      Jason Holder             5.75
# 50       Mukesh Kumar             5.50
# 220  Heinrich Klaasen             5.25

# %%
sns.set_theme(style='whitegrid', font_scale=1.2)

plt.figure(figsize=(10, 6))  
sns.barplot(data=top_10_expensive_batsmen, x="Player's List", y='COST IN ₹ (CR.)', dodge = False, palette = 'autumn')


plt.xlabel("Player's List")
plt.ylabel('COST IN ₹ (CR.)')

plt.title('Top 10 Expensive Players Sold', fontweight='bold', fontsize=16)

plt.xticks(rotation=45)


plt.show()

# %% [markdown]
# ### Q4) Top 5 expensive WicketKeepers sold

# %%
filtered_data = data[data['TYPE'] == 'WICKETKEEPER']
sorted_data = filtered_data.sort_values(by='COST IN ₹ (CR.)', ascending=False)
top_5_expensive_wk = sorted_data.head()

# %%
top_5_expensive_wk
# Out:
#         Player's List  Base Price          TYPE  COST IN ₹ (CR.)  \
# 119   Nicholas Pooran  20000000.0  WICKETKEEPER            16.00
# 220  Heinrich Klaasen  10000000.0  WICKETKEEPER             5.25
# 53          Phil Salt  20000000.0  WICKETKEEPER             2.00
# 3         K.S. Bharat   2000000.0  WICKETKEEPER             1.20
# 77      N. Jagadeesan   2000000.0  WICKETKEEPER             0.90
#
#      Cost IN $ (000) 2022 Squad                   Team
# 119           1920.0        SRH   Lucknow Super Giants
# 220            630.0        DNP    Sunrisers Hyderabad
# 53             240.0        DNP         Delhi Capitals
# 3              144.0         DC         Gujarat Titans
# 77             108.0        CSK  Kolkata Knight Riders

# %%
top_5_expensive_wk = top_5_expensive_wk.rename(columns={"Player's List": 'Name'})

top_5_expensive_wk = top_5_expensive_wk.rename(columns={"COST IN ₹ (CR.)": 'Cost'})

# %%
top_5_expensive_wk
# Out:
#                  Name  Base Price          TYPE   Cost  Cost IN $ (000)  \
# 119   Nicholas Pooran  20000000.0  WICKETKEEPER  16.00           1920.0
# 220  Heinrich Klaasen  10000000.0  WICKETKEEPER   5.25            630.0
# 53          Phil Salt  20000000.0  WICKETKEEPER   2.00            240.0
# 3         K.S. Bharat   2000000.0  WICKETKEEPER   1.20            144.0
# 77      N. Jagadeesan   2000000.0  WICKETKEEPER   0.90            108.0
#
#     2022 Squad                   Team
# 119        SRH   Lucknow Super Giants
# 220        DNP    Sunrisers Hyderabad
# 53         DNP         Delhi Capitals
# 3           DC         Gujarat Titans
# 77         CSK  Kolkata Knight Riders

# %%
name = top_5_expensive_wk['Name']
cost = top_5_expensive_wk['Cost']

plt.scatter(name, cost)

plt.xlabel('Player')
plt.ylabel('Cost in ₹ (CR.)')
plt.title('Top 5 Expensive Wicketkeepers', fontweight='bold', fontsize=16)

plt.plot(name, cost, 'r-', alpha=0.3)

plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ### Q5) Top 5 Expensive Bowlers sold

# %%
# Changing names of columns because its making analysis complicated
data = data.rename(columns={"Player's List": 'Name', 'COST IN ₹ (CR.)' : 'Cost in Cr', 'Cost IN $ (000)' : 'Cost in USD'})
data.head()
# Out:
#               Name  Base Price          TYPE  Cost in Cr  Cost in USD  \
# 0      Shivam Mavi   4000000.0        BOWLER         6.0        720.0
# 1    Joshua Little   5000000.0        BOWLER         4.4        528.0
# 2  Kane Williamson  20000000.0       BATSMAN         2.0        240.0
# 3      K.S. Bharat   2000000.0  WICKETKEEPER         1.2        144.0
# 4     Mohit Sharma   5000000.0        BOWLER         0.5         60.0
#
#   2022 Squad            Team
# 0        KKR  Gujarat Titans
# 1        DNP  Gujarat Titans
# 2        SRH  Gujarat Titans
# 3         DC  Gujarat Titans
# 4        DNP  Gujarat Titans

# %%
filtered_data_ = data[data['TYPE'] == 'BOWLER']
sorted_data = filtered_data_.sort_values(by='Cost in Cr', ascending=False)
top_5_expensive_bowlers = sorted_data.head()

# %%
top_5_expensive_bowlers
# Out:
#               Name  Base Price    TYPE  Cost in Cr  Cost in USD 2022 Squad  \
# 0      Shivam Mavi   4000000.0  BOWLER         6.0        720.0        KKR
# 50    Mukesh Kumar   2000000.0  BOWLER         5.5        660.0        DNP
# 1    Joshua Little   5000000.0  BOWLER         4.4        528.0        DNP
# 222    Adil Rashid  20000000.0  BOWLER         2.0        240.0        DNP
# 169   Reece Topley   7500000.0  BOWLER         1.9        228.0        DNP
#
#                            Team
# 0                Gujarat Titans
# 50               Delhi Capitals
# 1                Gujarat Titans
# 222         Sunrisers Hyderabad
# 169  Royal Challengers Banglore

# %%
sns.set_theme(style='whitegrid', font_scale=1.2)

plt.figure(figsize=(10, 6))  
sns.barplot(x='Cost in Cr', y='Name', data=top_5_expensive_bowlers, dodge = False, palette = 'crest')


plt.xlabel('Cost in ₹ (CR.)')
plt.ylabel('Player')
plt.title('Top 5 Expensive Bowlers', fontweight='bold', fontsize=16)
plt.show()

# %% [markdown]
# ### Q6) Did all teams purchase players to their full capacity ?

# %%
data = data[data['Team'] != 'Unsold']

# %%
team_counts = data['Team'].value_counts()

# %%
data_team_counts = pd.DataFrame(team_counts)
data_team_counts
# Out:
#                             Team
# Sunrisers Hyderabad           13
# Lucknow Super Giants          10
# Rajasthan Royals               9
# Kolkata Knight Riders          8
# Mumbai Indians                 8
# Gujarat Titans                 7
# Chennai Super Kings            7
# Royal Challengers Banglore     7
# Punjab Super Kings             6
# Delhi Capitals                 5
